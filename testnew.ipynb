# %%
import sympy

# %%
eps = 0.0001
x = sympy.Symbol("x")
expr = 6 + 0.5 * x
expr_iter = expr.subs(x, expr)
while (expr_iter - expr).subs(x, 0) >= eps:
    print(expr_iter)
    expr_iter = expr_iter.subs(x, expr)
# Out:
# 0.25*x + 9.0
# 0.125*x + 10.5
# 0.0625*x + 11.25
# 0.03125*x + 11.625
# 0.015625*x + 11.8125
# 0.0078125*x + 11.90625
# 0.00390625*x + 11.953125
# 0.001953125*x + 11.9765625
# 0.0009765625*x + 11.98828125
# 0.00048828125*x + 11.994140625
# 0.000244140625*x + 11.9970703125
# 0.0001220703125*x + 11.99853515625
# 6.103515625e-5*x + 11.999267578125
# 3.0517578125e-5*x + 11.9996337890625
# 1.52587890625e-5*x + 11.9998168945313
# 7.62939453125e-6*x + 11.9999084472656
# 3.814697265625e-6*x + 11.9999542236328
# 1.9073486328125e-6*x + 11.9999771118164
# 9.5367431640625e-7*x + 11.9999885559082
# 4.76837158203125e-7*x + 11.9999942779541
# 2.38418579101563e-7*x + 11.9999971389771
# 1.19209289550781e-7*x + 11.9999985694885
# 5.96046447753906e-8*x + 11.9999992847443
# 2.98023223876953e-8*x + 11.9999996423721
# 1.49011611938477e-8*x + 11.9999998211861
# 7.45058059692383e-9*x + 11.999999910593
# 3.72529029846191e-9*x + 11.9999999552965
# 1.86264514923096e-9*x + 11.9999999776483
# ...
